# %%
from google.colab import drive
#drive.mount('/content/drive', force_remount=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # T1

# %%
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height, height, ha='center', va='bottom', rotation=90, fontsize=12)
        #print(height)

#Valores dos agrupamentos
Borro = [49.3, 29.5, 51.5, 89.1, 75.6, 28.3, 53.9]
Leijoto = [62.1, 73.5, 62.1, 78.6, 75.5, 76.7, 71.4]
Santos  = [69.7, 65.3, 96.2, 100.0, 69.8, 86.3, 78.4]
Metodologia  = [65.0, 73.6, 80.0, 87.0,  74.5, 83.9, 77.3]

#Definindo o numero de colunas e o numero de agrupamentos
number_columns = len(Borro)
number_groups = 4

# Definindo a largura das barras
barWidth = 0.21

#Espaçamento entre barras
espacamentoEntreBarras = 0.00

#espaçamento de um grupo no outro
espacamentoEntreGrupos = 1.2

# Aumentando o gráfico
plt.rcParams['figure.figsize'] = (15,7)

fig, ax = plt.subplots()

# Definindo a posição das barras
#r1 = np.arange(len(Borro))
r1 = [x * espacamentoEntreGrupos + espacamentoEntreBarras for x in range(number_columns)]
r2 = [x + barWidth + espacamentoEntreBarras for x in r1]
r3 = [x + barWidth + espacamentoEntreBarras for x in r2]
r4 = [x + barWidth + espacamentoEntreBarras for x in r3]

# Criando as barras
label1 = plt.bar(r1, Borro, color='#704F97', width=barWidth, label='Borro et al (2006)')
label2 = plt.bar(r2, Leijoto, color='#91B643', width=barWidth, label='Leijôto (2014)')
label3 = plt.bar(r3, Santos, color='#AF3330', width=barWidth, label='Santos (2016)')
label4 = plt.bar(r4, Metodologia, color='#3771B8', width=barWidth, label='Metodologia Proposta')

# Adicionando legendas nas barras
plt.xlabel('Class protein')
plt.xticks([r + barWidth + espacamentoEntreBarras + 0.15 for r in r1], ['Tra.', 'Oxi.', 'Lia.', 'Lig.', 'Iso.', 'Hid.', 'Ave.'])

plt.ylabel('Precision')
plt.yticks(np.arange(0, 120, 10))

plt.title('Comparison between methodologies')


#preenche os valores nas barras
autolabel(label1)
autolabel(label2)
autolabel(label3)
autolabel(label4)

#Coloca a legenda fora do gráfico
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.10), fancybox=True, shadow=True, ncol=4)

# Criando a legenda e exibindo o gráfico
#plt.legend()
plt.show()
#plt.savefig('drive/My D

# %% [markdown]
# # T2

# %%
def autolabel(rects):
    for rect in rects:
        width = rect.get_width()
        height = rect.get_height()
        ypos = rect.get_y() + height/2
        ax.text(width + 5.0, ypos - 0.11, width, ha='center', va='bottom', rotation=0, fontsize=12)

#Valores dos agrupamentos
Borro = [49.3, 29.5, 51.5, 89.1, 75.6, 28.3, 53.9]
Leijoto = [62.1, 73.5, 62.1, 78.6, 75.5, 76.7, 71.4]
Santos  = [69.7, 65.3, 96.2, 100.0, 69.8, 86.3, 78.4]
Metodologia  = [65.0, 73.6, 80.0, 87.0,  74.5, 83.9, 77.3]

#Definindo o numero de colunas e o numero de agrupamentos
number_columns = len(Borro)
number_groups = 4

# Definindo a largura das barras
barWidth = 0.21

#Espaçamento entre barras
espacamentoEntreBarras = 0.00

#espaçamento de um grupo no outro
espacamentoEntreGrupos = 1.2

# Aumentando o gráfico
plt.rcParams['figure.figsize'] = (7,10)

fig, ax = plt.subplots()

# Definindo a posição das barras
#r1 = np.arange(len(Borro))
r1 = [(x * espacamentoEntreGrupos + espacamentoEntreBarras) *-1 for x in range(number_columns)]
r2 = [(x - barWidth - espacamentoEntreBarras) for x in r1]
r3 = [x - barWidth - espacamentoEntreBarras for x in r2]
r4 = [x - barWidth - espacamentoEntreBarras for x in r3]

# Criando as barras
label1 = plt.barh(r1, Borro, barWidth, color='#704F97', label='Borro et al (2006)')
label2 = plt.barh(r2, Leijoto, barWidth, color='#91B643', label='Leijôto (2014)')
label3 = plt.barh(r3, Santos, barWidth, color='#AF3330', label='Santos (2016)')
label4 = plt.barh(r4, Metodologia, barWidth, color='#3771B8', label='Metodologia Proposta')

# Adicionando legendas nas barras
plt.ylabel('Class protein')
plt.yticks([r - barWidth - espacamentoEntreBarras - 0.12 for r in r1], ['Tra.', 'Oxi.', 'Lia.', 'Lig.', 'Iso.', 'Hid.', 'Ave.'])

plt.xlabel('Precision')
plt.xticks(np.arange(0, 120, 10))

plt.title('Comparison between methodologies')

#preenche os valores nas barras
autolabel(label1)
autolabel(label2)
autolabel(label3)
autolabel(label4)

#Coloca a legenda fora do gráfico
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.10), fancybox=True, shadow=True, ncol=4)

# Criando a legenda e exibindo o gráfico
#plt.legend()
plt.show()
#plt.savefig('drive/My Drive/GraficosPython/'+ 'graficoExemplo.png')

# %% [markdown]
# # T3

# %%
import matplotlib.pyplot as plt
import numpy as np

def autolabel(ax, rects):
    for rect in rects:
        width = rect.get_width()
        height = rect.get_height()
        ypos = rect.get_y() + height/2
        ax.text(width + width*0.12, ypos - 0.15, width, ha='center', va='bottom', rotation=0, fontsize=12)

#Valores dos agrupamentos

#format: oxi. ; hidro; iso; lia; lig; trans; avg
Gabriela_precision = [89.93, 76.2, 92.5, 93.46, 82.62, 73.35,84.68]
Brito_precision = [88.60, 83.90, 89.60, 70.60, 89.70, 87.90, 85.05 ]
EnrichedGA_precision  = [92.98,87.15,86.93,80.21,84.61,93.77,87.61]
AUC_precision  = [92.79,86.27,85.76,80.02,86.25,94.25,87.56]
GA_precision  = [92.38,86.96,84.53,78.11,82.62,93.74,86.39]
SValuable_precision  = [94.50,80.43,84.91,82.78,87.93,95.88,87.74]

#Valores dos agrupamentos
Gabriela_recall = [79.48, 86.06, 60.47, 70.26, 55.13, 82, 72.23 ]
Brito_recall = [86.60, 93.20, 55.90, 55.50, 75.30, 91.70, 76.37 ]
EnrichedGA_recall  = [92.91, 92.36, 75.18, 78.20, 74.76, 92.32, 84.29]
AUC_recall  = [91.94,92.90,72.50,76.83,75.33,92.32,83.64]
GA_recall  = [92.27,91.58,74.28,77.48,74.10,92.15,83.64]
SValuable_recall  = [87.05,95.06,62.36,77.05,70.67,90.19,80.39]

#Valores dos agrupamentos
Gabriela_fmeasure = [84.38, 80.83, 73.13, 80.21, 66.13, 77.44, 77.02]
Brito_fmeasure = [87.60, 88.30, 68.90, 62.10, 81.90, 89.80, 79.77 ]
EnrichedGA_fmeasure  = [92.93, 89.68, 80.55, 79.17, 79.31, 93.04, 85.78]
AUC_fmeasure  = [92.35,89.46,78.49,78.37,80.38,93.26,85.39]
GA_fmeasure  = [92.32,89.20,78.97,77.77,78.05,92.93,84.88]
SValuable_fmeasure  = [90.61,87.13,71.79,79.74,78.23,92.94,83.41]

#Definindo o numero de colunas e o numero de agrupamentos
number_columns = 7 #classes+avg
number_groups = 6

#definindo cores
Gabriela_color = '#acc4b4';
Brito_color = '#D3cba2';
Svaluable_color = '#95bcc5';
GA_color = '#5a8a9b';
AUC_color = '#324f61';
EnrichedGA_color = '#152b34';


# Definindo a largura das barras
barWidth = 0.35

#Espaçamento entre barras
espacamentoEntreBarras = 0.0

#espaçamento de um grupo no outro
espacamentoEntreGrupos = 3.0

# Aumentando o gráfico
plt.rcParams['figure.figsize'] = (15,17)

fig, ((ax0, ax1, ax2)) = plt.subplots(nrows=1, ncols=3)

# Definindo a posição das barras
r1 = [(x * espacamentoEntreGrupos + espacamentoEntreBarras) *-1 for x in range(number_columns)]
r2 = [(x - barWidth - espacamentoEntreBarras) for x in r1]
r3 = [x - barWidth - espacamentoEntreBarras for x in r2]
r4 = [x - barWidth - espacamentoEntreBarras for x in r3]
r5 = [x - barWidth - espacamentoEntreBarras for x in r4]
r6 = [x - barWidth - espacamentoEntreBarras for x in r5]

# Criando as barras
label1 = ax0.barh(r1, Gabriela_precision, barWidth, color=Gabriela_color, label='Santos et al. [1]')#'Santos et al. (2021)')
label2 = ax0.barh(r2, Brito_precision, barWidth, color=Brito_color, label='Brito et al. [11]')#'Brito et al. (2019)')
label3 = ax0.barh(r3, SValuable_precision, barWidth, color=Svaluable_color, label='Svaluable')
label4 = ax0.barh(r4, GA_precision, barWidth, color=GA_color, label='GA')
label5 = ax0.barh(r5, AUC_precision, barWidth, color=AUC_color, label='AUC')
label6 = ax0.barh(r6, EnrichedGA_precision, barWidth, color=EnrichedGA_color, label='Enriched_GA')


ax0.set_xticks(np.arange(0, 140, 20))
ax0.set_yticks([r - barWidth - espacamentoEntreBarras - 0.12 for r in r1])
#ax0.set_yticklabels(['Tra.', 'Oxi.', 'Lia.', 'Lig.', 'Iso.', 'Hid.', 'Ave.'])
ax0.set_yticklabels(['Oxidoreductases', 'Hydrolases', 'Isomerases', 'Lyases', 'Ligases', 'Transferases', 'Average'])
ax0.set_title('Precision')
ax0.set_ylabel('Class')

autolabel(ax0, label1)
autolabel(ax0, label2)
autolabel(ax0, label3)
autolabel(ax0, label4)
autolabel(ax0, label5)
autolabel(ax0, label6)


# Criando as barras
label1 = ax1.barh(r1, Gabriela_recall, barWidth, color=Gabriela_color, label='Santos et al. [1]')#'Santos et al. (2021)')
label2 = ax1.barh(r2, Brito_recall, barWidth, color=Brito_color, label='Brito et al. [11]')#'Brito et al. (2019)')
label3 = ax1.barh(r3, SValuable_recall, barWidth, color=Svaluable_color, label='Svaluable')
label4 = ax1.barh(r4, GA_recall, barWidth, color=GA_color, label='GA')
label5 = ax1.barh(r5, AUC_recall, barWidth, color=AUC_color, label='AUC')
label6 = ax1.barh(r6, EnrichedGA_recall, barWidth, color=EnrichedGA_color, label='Enriched_GA')

ax1.set_xticks(np.arange(0, 140, 20))
ax1.set_yticks([r - barWidth - espacamentoEntreBarras - 0.12 for r in r1])
#ax1.set_yticklabels(['Tra.', 'Oxi.', 'Lia.', 'Lig.', 'Iso.', 'Hid.', 'Ave.'])
ax1.set_yticklabels(['', '', '', '', '', '', ''])
ax1.set_title('Recall')
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=number_columns)

autolabel(ax1, label1)
autolabel(ax1, label2)
autolabel(ax1, label3)
autolabel(ax1, label4)
autolabel(ax1, label5)
autolabel(ax1, label6)


# Criando as barras
label1 = ax2.barh(r1, Gabriela_fmeasure, barWidth, color=Gabriela_color, label='Santos et al. [1]')#'Santos et al. (2021)')
label2 = ax2.barh(r2, Brito_fmeasure, barWidth, color=Brito_color, label='Brito et al. [11]')#'Brito et al. (2019)')
label3 = ax2.barh(r3, SValuable_fmeasure, barWidth, color=Svaluable_color, label='Svaluable')
label4 = ax2.barh(r4, GA_fmeasure, barWidth, color=GA_color, label='GA')
label5 = ax2.barh(r5, AUC_fmeasure, barWidth, color=AUC_color, label='AUC')
label6 = ax2.barh(r6, EnrichedGA_fmeasure, barWidth, color=EnrichedGA_color, label='Enriched_GA')

ax2.set_xticks(np.arange(0, 140, 20))
ax2.set_yticks([r - barWidth - espacamentoEntreBarras - 0.12 for r in r1])
#ax2.set_yticklabels(['Tra.', 'Oxi.', 'Lia.', 'Lig.', 'Iso.', 'Hid.', 'Ave.'])
ax2.set_yticklabels(['', '', '', '', '', '', ''])
ax2.set_title('F-Measure')

autolabel(ax2, label1)
autolabel(ax2, label2)
autolabel(ax2, label3)
autolabel(ax2, label4)
autolabel(ax2, label5)
autolabel(ax2, label6)

#plt.suptitle('Comparison between methodologies', fontsize=16)
plt.savefig('/content/r.png', format='png', dpi=500, bbox_inches = 'tight')
plt.show()

# %%
def autolabel(ax, rects):
    for rect in rects:
        width = rect.get_width()
        height = rect.get_height()
        ypos = rect.get_y() + height/2
        ax.text(width + 7.0, ypos - 0.11, width, ha='center', va='bottom', rotation=0, fontsize=16)

#Valores dos agrupamentos
Borro_precision = [49.3, 29.5, 51.5, 89.1, 75.6, 28.3, 53.9]
Leijoto_precision = [62.1, 73.5, 62.1, 78.6, 75.5, 76.7, 71.4]
Santos_precision  = [69.7, 65.3, 96.2, 100.0, 69.8, 86.3, 78.4]
Metodologia_precision  = [65.0, 73.6, 80.0, 87.0,  74.5, 83.9, 77.3]

#Valores dos agrupamentos
Borro_recall = [38.5, 24.0, 42.0, 62.8, 36.0, 69.1, 45.4]
Leijoto_recall = [72.5, 65.8, 60.0, 61.1, 70.2, 75.8, 67.6]
Santos_recall = [84.6, 60.3, 75.4, 62.5, 66.1, 85.2, 72.4]
Metodologia_recall = [79.7, 68.0, 50.0, 64.5, 69.1, 87.0, 69.7]

#Valores dos agrupamentos
Borro_fmeasure = [43.2, 26.5, 46.3, 73.7, 48.8, 40.1, 46.4]
Leijoto_fmeasure = [66.9, 69.4, 61.0, 68.8, 72.7, 76.3, 69.2]
Santos_fmeasure = [76.4, 62.7, 82.1, 71.4, 67.9, 85.7, 74.4]
Metodologia_fmeasure = [72.0, 71.1, 61.5, 74.1, 71.7, 85.5, 72.7]

#Definindo o numero de colunas e o numero de agrupamentos
number_columns = 7
number_groups = 4


# Definindo a largura das barras
barWidth = 0.21

#Espaçamento entre barras
espacamentoEntreBarras = 0.0

#espaçamento de um grupo no outro
espacamentoEntreGrupos = 1.2

# Aumentando o gráfico
plt.rcParams['figure.figsize'] = (17,10)

fig, ((ax0, ax1, ax2)) = plt.subplots(nrows=1, ncols=3)

# Definindo a posição das barras
r1 = [(x * espacamentoEntreGrupos + espacamentoEntreBarras) *-1 for x in range(number_columns)]
r2 = [(x - barWidth - espacamentoEntreBarras) for x in r1]
r3 = [x - barWidth - espacamentoEntreBarras for x in r2]
r4 = [x - barWidth - espacamentoEntreBarras for x in r3]

# Criando as barras
label1 = ax0.barh(r1, Borro_precision, barWidth, color='#704F97', label='Borro et al (2006)')
label2 = ax0.barh(r2, Leijoto_precision, barWidth, color='#91B643', label='Leijôto (2014)')
label3 = ax0.barh(r3, Santos_precision, barWidth, color='#AF3330', label='Santos (2016)')
label4 = ax0.barh(r4, Metodologia_precision, barWidth, color='#3771B8', label='Metodologia Proposta')

ax0.set_xticks(np.arange(0, 140, 20))
ax0.set_yticks([r - barWidth - espacamentoEntreBarras - 0.12 for r in r1])
ax0.set_yticklabels(['Tra.', 'Oxi.', 'Lia.', 'Lig.', 'Iso.', 'Hid.', 'Ave.'])
ax0.set_title('Precision')
ax0.set_ylabel('Class')

autolabel(ax0, label1)
autolabel(ax0, label2)
autolabel(ax0, label3)
autolabel(ax0, label4)


# Criando as barras
label1 = ax1.barh(r1, Borro_recall, barWidth, color='#704F97', label='Borro et al (2006)')
label2 = ax1.barh(r2, Leijoto_recall, barWidth, color='#91B643', label='Leijôto (2014)')
label3 = ax1.barh(r3, Santos_recall, barWidth, color='#AF3330', label='Santos (2016)')
label4 = ax1.barh(r4, Metodologia_recall, barWidth, color='#3771B8', label='Metodologia Proposta')

ax1.set_xticks(np.arange(0, 140, 20))
ax1.set_yticks([r - barWidth - espacamentoEntreBarras - 0.12 for r in r1])
ax1.set_yticklabels(['Tra.', 'Oxi.', 'Lia.', 'Lig.', 'Iso.', 'Hid.', 'Ave.'])
ax1.set_title('Recall')
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=4)

autolabel(ax1, label1)
autolabel(ax1, label2)
autolabel(ax1, label3)
autolabel(ax1, label4)


# Criando as barras
label1 = ax2.barh(r1, Borro_fmeasure, barWidth, color='#704F97', label='Borro et al (2006)')
label2 = ax2.barh(r2, Leijoto_fmeasure, barWidth, color='#91B643', label='Leijôto (2014)')
label3 = ax2.barh(r3, Santos_fmeasure, barWidth, color='#AF3330', label='Santos (2016)')
label4 = ax2.barh(r4, Metodologia_fmeasure, barWidth, color='#3771B8', label='Metodologia Proposta')

ax2.set_xticks(np.arange(0, 140, 20))
ax2.set_yticks([r - barWidth - espacamentoEntreBarras - 0.12 for r in r1])
ax2.set_yticklabels(['Tra.', 'Oxi.', 'Lia.', 'Lig.', 'Iso.', 'Hid.', 'Ave.'])
ax2.set_title('F-Measure')

autolabel(ax2, label1)
autolabel(ax2, label2)
autolabel(ax2, label3)
autolabel(ax2, label4)

#plt.suptitle('Comparison between methodologies', fontsize=16)
plt.show()
